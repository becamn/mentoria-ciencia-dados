# %% [markdown]
# ### **Projeto 1**: Recriando a classe do Pandas
#
# Nesse projeto temos como objetivo revisar vários dos conceitos aprendidos até aqui (bases de python 🐍, funções e programação orientada à objeto) e reconstruir de maneira simplificada alguns métodos de uma das bibliotecas mais utilizadas no universo de ciência de dados: o 🐼 **Pandas** 🐼. Para isso, você deve criar uma classe chamada DataFrame_raiz, inicializando o objeto DataFrame do Pandas (*lembre-se: inicializar uma classe é criar uma função de init com seus atributos necessários, os atributos serão especificados*). Em seguida, você deve criar alguns dos métodos mais usados no nosso dia a dia, para isso vamos especificar quais serão os métodos requeridos, seus argumentos necessários e alguns testes, e assim conferirem se tá rodando tudo certinho 🏆. Para cada método será especificado sua definição, estrutura base e exemplo de utilização no pandas.
#
# *obs: Todos exemplos terão como base esses dois dataframes:*
#
# ``` python
# df_1 = pd.DataFrame(
#     data={
#         'column_A': [1,2,3],
#         'column_B': [2,6,7],
#         'column_C': [2,5,6]
#     }
# )
#
# df_2 = pd.DataFrame(
#     data={
#         'column_A': [10,24,32],
#         'column_B': [25,64,71],
#         'column_C': [23,5,36]
#     }
# )
# ```
# ### Atributos da classe
#     > columns : retorna uma lista com o nome das colunas do DataFrame
#     > shape: retorna uma tuple com o número de linhas e colunas do DataFrame (n linhas, n colunas)
#     > T: retorna o DataFrame transposto
#
# ### **01-** Método soma:
# **Definição**: Esse método retorna a soma do axis especificado de um dataframe.
#
# **Estrutura:**
# ``` python
# def sum(self, axis=1):
#     ...
#     return ...
# ```
#
# **Exemplo:**
#
# `código`
# ``` python
# df_1.sum()
# ```
# `output`
# ``` python
# column_A 6
# column_B 15
# column_C 13
# ```
#
# ### **02-** Método rename columns:
# **Definição**: Esse método renomeia as colunas de um dataframe. Obs: a função/ valores tem que ser únicos
#
#  **Estrutura:**
# ``` python
# def rename(self, dict):
#     ...
#     return ...
# ```
#
# **Exemplo:**
#
# `código`
# ``` python
# df_1.rename(columns={'column_A': 'teste'})
# ```
# `output`
# ```python
#         teste        column_B      column_C
# 0             1             2              2
# 1             2             6              5
# 2             3             7              6
# ```
#
# ### **03-** Método Média:
# **Definição**: Esse método retorna a média dos valores do axis requerido.
#
#  **Estrutura:**
# ``` python
# def mean(self, axis=0):
#     ...
#     return ...
# ```
#
# **Exemplo:**
#
# `código`
# ``` python
# df_1.mean()
# ```
# `output`
# ```python
# column_A    2.000000
# column_B    5.000000
# column_C    4.333333
# ```
#
# ### **04-** Método Mediana:
# **Definição**: Esse método retorna a mediana dos valores do axis requerido.
#
#  **Estrutura:**
# ``` python
# def median(self, axis=0):
#     ...
#     return ...
# ```
#
# **Exemplo:**
#
# `código`
# ``` python
# df_1.median()
# ```
# `output`
# ```python
# column_A    2.0
# column_B    6.0
# column_C    5.0
# ```
# ### **05-** Método Head:
# **Definição**: Esse método retorna as 5 primeiras linhas de um dataframe.
#
#  **Estrutura:**
# ``` python
# def head(self):
#     ...
#     return ...
# ```
#
# **Exemplo:**
#
# `código`
# ``` python
# df_1.head()
# ```
# `output`
# ```python
#   column_A	column_B	column_C
# 0	  1	        2	       2
# 1	  2	        6	       5
# 2	  3	        7	       6
# ```
#
# ### **06-** Método Drop:
# **Definição**: Esse método retorna o DataFrame sem as colunas especificadas (dropadas).
#
#  **Estrutura:**
# ``` python
# def drop(self, columns):
#     ...
#     return ...
# ```
#
# **Exemplo:**
#
# `código`
# ``` python
# df_1.drop(columns=['column_C'])
# ```
# `output`
# ```python
#   column_A	column_B
# 0	  1	        2
# 1	  2	        6
# 2	  3	        7
# ```
